# %% [markdown]
# <h2> A.Wrangling Data

# %% [markdown]
# <b>1. Tahap Persiapan

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
import seaborn as sns

# %% [markdown]
# <b>2. Gathering data

# %% [markdown]
# 2.1. Load data customer

# %%
customer_df=pd.read_csv('customers.csv')
customer_df.head()
# Out:
#    customer_id customer_name             gender  age  \
# 0            1       fulan 1             Female   30
# 1            2       fulan 2  Prefer not to say   69
# 2            3       fulan 3  Prefer not to say   59
# 3            4       fulan 4  Prefer not to say   67
# 4            5       fulan 5  Prefer not to say   30
#
#                      home_address  zip_code               city  \
# 0  8606 Victoria TerraceSuite 560      5464      Johnstonhaven
# 1      8327 Kirlin SummitApt. 461      8223    New Zacharyfort
# 2       269 Gemma SummitSuite 109      5661           Aliburgh
# 3       743 Bailey GroveSuite 141      1729  South Justinhaven
# 4         48 Hyatt ManorSuite 375      4032     Griffithsshire
#
#                           state    country
# 0            Northern Territory  Australia
# 1               South Australia  Australia
# 2  Australian Capital Territory  Australia
# 3                    Queensland  Australia
# 4                    Queensland  Australia

# %% [markdown]
# 2.2. Load data orders

# %%
orders_df=pd.read_csv('orders.csv')
orders_df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date
# 0         1           64    30811  2021-8-30    2021-09-24
# 1         2          473    50490   2021-2-3    2021-02-13
# 2         3          774    46763  2021-10-8    2021-11-03
# 3         4          433    39782   2021-5-6    2021-05-19
# 4         5          441    14719  2021-3-23    2021-03-24

# %% [markdown]
# 2.3. Load data products

# %%
products_df=pd.read_csv('products.csv')
products_df.head()
# Out:
#    product_id product_type  product_name size colour  price  quantity  \
# 0           0        Shirt  Oxford Cloth   XS    red    114        66
# 1           1        Shirt  Oxford Cloth    S    red    114        53
# 2           2        Shirt  Oxford Cloth    M    red    114        54
# 3           3        Shirt  Oxford Cloth    L    red    114        69
# 4           4        Shirt  Oxford Cloth   XL    red    114        47
#
#                                     description
# 0  A red coloured, XS sized, Oxford Cloth Shirt
# 1   A red coloured, S sized, Oxford Cloth Shirt
# 2   A red coloured, M sized, Oxford Cloth Shirt
# 3   A red coloured, L sized, Oxford Cloth Shirt
# 4  A red coloured, XL sized, Oxford Cloth Shirt

# %% [markdown]
# 2.4. Load data sales

# %%
sales_df=pd.read_csv('sales.csv')
sales_df.head()
# Out:
#    sales_id  order_id  product_id  price_per_unit  quantity  total_price
# 0         0         1         218             106         2        212.0
# 1         1         1         481             118         1        118.0
# 2         2         1           2              96         3        288.0
# 3         3         1        1002             106         2        212.0
# 4         4         1         691             113         3        339.0

# %% [markdown]
# <b>3. Assessing Data

# %% [markdown]
# 3.1. Menilai data customers_df

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    1007 non-null   int64
#  1   customer_name  1007 non-null   object
#  2   gender         989 non-null    object
#  3   age            1007 non-null   int64
#  4   home_address   1007 non-null   object
#  5   zip_code       1007 non-null   int64
#  6   city           1007 non-null   object
#  7   state          1007 non-null   object
#  8   country        1007 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 70.9+ KB

# %%
##cek missing value
customer_df.isna().sum()
# Out:
# customer_id       0
# customer_name     0
# gender           18
# age               0
# home_address      0
# zip_code          0
# city              0
# state             0
# country           0
# dtype: int64

# %%
print("Jumalh duplikat pada data customer: ", customer_df.duplicated().sum())
# Out:
# Jumalh duplikat pada data customer:  6

# %%
customer_df.describe()
# Out:
#        customer_id          age     zip_code
# count  1007.000000  1007.000000  1007.000000
# mean    501.726912    50.929494  5012.538232
# std     288.673238    30.516299  2885.836112
# min       1.000000    20.000000     2.000000
# 25%     252.500000    34.000000  2403.500000
# 50%     502.000000    50.000000  5087.000000
# 75%     751.500000    65.000000  7493.500000
# max    1000.000000   700.000000  9998.000000

# %% [markdown]
# 3.2 Menilai data orders_df

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1000 non-null   int64
#  1   customer_id    1000 non-null   int64
#  2   payment        1000 non-null   int64
#  3   order_date     1000 non-null   object
#  4   delivery_date  1000 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 39.2+ KB

# %%
print("Jumlah duplikat pada data orders: ", orders_df.duplicated().sum())
# Out:
# Jumlah duplikat pada data orders:  0

# %%
orders_df.describe()
# Out:
#           order_id  customer_id       payment
# count  1000.000000  1000.000000   1000.000000
# mean    500.500000   506.640000  33972.936000
# std     288.819436   277.115502  14451.609047
# min       1.000000     1.000000  10043.000000
# 25%     250.750000   275.250000  21329.250000
# 50%     500.500000   515.000000  33697.500000
# 75%     750.250000   737.250000  46249.000000
# max    1000.000000  1000.000000  59910.000000

# %% [markdown]
# 3.2. Menilai data products_df

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1266 entries, 0 to 1265
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    1266 non-null   int64
#  1   product_type  1266 non-null   object
#  2   product_name  1266 non-null   object
#  3   size          1266 non-null   object
#  4   colour        1266 non-null   object
#  5   price         1266 non-null   int64
#  6   quantity      1266 non-null   int64
#  7   description   1266 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 79.2+ KB

# %% [markdown]
# 3.3. Menilai Data sales_df

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sales_id        5000 non-null   int64
#  1   order_id        5000 non-null   int64
#  2   product_id      5000 non-null   int64
#  3   price_per_unit  5000 non-null   int64
#  4   quantity        5000 non-null   int64
#  5   total_price     4981 non-null   float64
# dtypes: float64(1), int64(5)
# memory usage: 234.5 KB

# %%
##cek missing value
sales_df.isna().sum()
# Out:
# sales_id           0
# order_id           0
# product_id         0
# price_per_unit     0
# quantity           0
# total_price       19
# dtype: int64

# %%
## cek duplikasi data
print("Jumlah duplikat pada data sales: ", sales_df.duplicated().sum())
# Out:
# Jumlah duplikat pada data sales:  0

# %%
sales_df.describe()
# Out:
#           sales_id     order_id   product_id  price_per_unit    quantity  \
# count  5000.000000  5000.000000  5000.000000     5000.000000  5000.00000
# mean   2499.500000   503.038200   634.053200      103.501600     1.99240
# std    1443.520003   285.964418   363.255794        9.195004     0.80751
# min       0.000000     1.000000     1.000000       90.000000     1.00000
# 25%    1249.750000   258.000000   323.000000       95.000000     1.00000
# 50%    2499.500000   504.500000   635.000000      102.000000     2.00000
# 75%    3749.250000   749.000000   951.000000      112.000000     3.00000
# max    4999.000000   999.000000  1259.000000      119.000000     3.00000
#
#        total_price
# count  4981.000000
# mean    206.307368
# std      86.352449
# min      90.000000
# 25%     112.000000
# 50%     204.000000
# 75%     285.000000
# max     357.000000

# %% [markdown]
# <b>4. Cleaning Data

# %% [markdown]
# 4.1. Membersihkan Data customers_df

# %%
## drop data yang duplikat
customer_df.drop_duplicates(inplace=True)

# %%
## Menangani missing value

## melihat data yang mengandung missing value tersebut menggunakan teknik filtering
customer_df[customer_df.gender.isna()]
# Out:
#      customer_id customer_name gender  age                     home_address  \
# 38            39      fulan 39    NaN   80  7440 Cameron Estate DrSuite 628
# 167          168     fulan 168    NaN   27         2781 Berge MallSuite 452
# 322          322     fulan 322    NaN   30        593 Becker CircleApt. 333
# 393          393     fulan 393    NaN   34          5158 Levi HillSuite 531
# 442          442     fulan 442    NaN   26           5157 Feil RoadApt. 633
# 722          720     fulan 720    NaN   40         31 Jordan ParadeApt. 400
# 745          743     fulan 743    NaN   57   09 Christopher StreetSuite 967
# 773          771     fulan 771    NaN   74     7367 Wright JunctionApt. 773
# 798          795     fulan 795    NaN   49          487 Summer MewsApt. 874
# 801          798     fulan 798    NaN   56           27 Aiden KnollApt. 875
# 825          822     fulan 822    NaN   59        41 Jenkins KnollSuite 438
# ...

# %% [markdown]
# <small>Karna data diatas masih mengandung informasi yang penting, maka sayang untuk di hapus, oleh karena itu, kita atasi missing valuenya dengan metode imputation.
# Kita akan menggunakan nilai yang dominan sebagai pengganti missing value

# %%
# metode imputation untuk menangani missing value.
## Cari nilai yang dominan
customer_df.gender.value_counts()
# Out:
# gender
# Prefer not to say    725
# Male                 143
# Female               115
# Name: count, dtype: int64

# %%
# isi missing value dengan nilai yang dominan
customer_df.fillna(value="Prefer not to say", inplace=True)

# %%
## cetak kembali jumlah data yang hilang
customer_df.isna().sum()
# Out:
# customer_id      0
# customer_name    0
# gender           0
# age              0
# home_address     0
# zip_code         0
# city             0
# state            0
# country          0
# dtype: int64

# %% [markdown]
# Menangani inaccurate value

# %%
## cek baris mana yang mengandung inaccurate value
customer_df[customer_df.age==customer_df.age.max()]
# Out:
#      customer_id customer_name             gender  age  \
# 967          961     fulan 961  Prefer not to say  700
#
#                    home_address  zip_code        city            state  \
# 967  29 Farrell ParadeSuite 818      6528  New Joseph  South Australia
#
#        country
# 967  Australia

# %% [markdown]
# <small>Kita bisa melihat bahwa nilai age yang tidak akurat itu  adalah 700.Bisa kita simpulkan bahwa ini adalah human error, yang harusnya 70 jadi 700 sehingga kita bisa menggantinya dengan 70

# %%
## ganti yang menganadung inaccurate value dengan nilai yang valid
customer_df.age.replace(customer_df.age.max(), 70, inplace=True)

# %%
# cek apakah masih ada yg tidak akurat
customer_df[customer_df.age == customer_df.age.max()]
# Out:
#      customer_id customer_name             gender  age  \
# 215          216     fulan 216  Prefer not to say  500
#
#                home_address  zip_code       city               state  \
# 215  038 Haley MewsApt. 810      3991  Bayertown  Northern Territory
#
#        country
# 215  Australia

# %%
## ganti yang menganadung inaccurate value dengan nilai yang valid
customer_df.age.replace(customer_df.age.max(), 50, inplace=True)

# %%
customer_df.describe()
# Out:
#        customer_id          age     zip_code
# count  1001.000000  1001.000000  1001.000000
# mean    500.942058    49.874126  5000.693307
# std     289.013599    17.644663  2886.084454
# min       1.000000    20.000000     2.000000
# 25%     251.000000    34.000000  2398.000000
# 50%     501.000000    50.000000  5079.000000
# 75%     751.000000    65.000000  7454.000000
# max    1000.000000    80.000000  9998.000000

# %% [markdown]
# 4.2. Membersihkan Data orders_df

# %% [markdown]
# <small>Masalah yang ada pada data order_df adalah kesalahan tipe data.Untuk mengatasi masalah ini, kita akan mengganti tipe data pada kolom order_date & delivery_date menjadi datetime

# %%
# ganti tipe data order_date dan delivery_date menjadi tipe data datetime
date_columns = ['order_date', 'delivery_date']

for col in date_columns:
    orders_df[col] = pd.to_datetime(orders_df[col])

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1000 non-null   int64
#  1   customer_id    1000 non-null   int64
#  2   payment        1000 non-null   int64
#  3   order_date     1000 non-null   datetime64[ns]
#  4   delivery_date  1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), int64(3)
# memory usage: 39.2 KB

# %% [markdown]
# 4.3. Membersihkan data yang ada pada product_df

# %% [markdown]
# <small>Pada data product_df terdapat 6 data yang terduplikasi, oleh karna itu perlu kita buang

# %%
## buang data duplikat yang ada pada data product_df
products_df.drop_duplicates(inplace=True)

# %% [markdown]
# 4.4. Membersihkan Data sales_df

# %% [markdown]
# <small>Pada data sales_df, terdapat 19 missing value pada kolom total_price.

# %%
# Cek baris mana yang missing value
sales_df[sales_df.isna().any(axis=1)]
# Out:
#       sales_id  order_id  product_id  price_per_unit  quantity  total_price
# 9            9         2        1196             105         1          NaN
# 121        121        27        1027              90         3          NaN
# 278        278        63         360              94         2          NaN
# 421        421        95        1091             115         1          NaN
# 489        489       108        1193             105         3          NaN
# 539        539       117         405             119         2          NaN
# 636        636       134         653              93         3          NaN
# 687        687       145        1138             102         1          NaN
# 854        854       177          64             104         1          NaN
# 1079      1079       222         908              94         3          NaN
# 1193      1193       248        1121             102         2          NaN
# ...

# %% [markdown]
# <small>Berdasarkan tampilan data yg ada pada sales_df, kita menemukan bahwa nilai total_price merupakan hasil perkalian antara price_per_unit dan quantity. Kita dapat menggunakan pola ini untuk menangani missing value pada kolom total_price.

# %%
sales_df["total_price"] = sales_df["price_per_unit"] * sales_df["quantity"]

# %%
sales_df.isna().sum()
# Out:
# sales_id          0
# order_id          0
# product_id        0
# price_per_unit    0
# quantity          0
# total_price       0
# dtype: int64

# %% [markdown]
# <h2> B. Exploratory Data

# %% [markdown]
# <h3>1. Eksplorasi Data customers_df

# %%
customer_df.describe(include="all")
# Out:
#         customer_id customer_name             gender          age  \
# count   1001.000000          1001               1001  1001.000000
# unique          NaN          1000                  3          NaN
# top             NaN     fulan 943  Prefer not to say          NaN
# freq            NaN             2                743          NaN
# mean     500.942058           NaN                NaN    49.874126
# std      289.013599           NaN                NaN    17.644663
# min        1.000000           NaN                NaN    20.000000
# 25%      251.000000           NaN                NaN    34.000000
# 50%      501.000000           NaN                NaN    50.000000
# 75%      751.000000           NaN                NaN    65.000000
# max     1000.000000           NaN                NaN    80.000000
#
#                       home_address     zip_code     city            state  \
# count                         1001  1001.000000     1001             1001
# ...

# %% [markdown]
# <small>Berdasarkan ringkasan statistik, terdapat 1001 pelanggan dengan rentang usia 20-80 tahun, rata-rata usia 49.87 tahun, dan standar deviasi 17.64 tahun. Informasi ini memberikan kitagambaran bahwa segmentasi pelanggan mencakup berbagai rentang usia, dari remaja hingga lanjut usia.

# %%
## Demografi data customer_df
customer_df.groupby(by="gender").agg({
    "customer_id": "nunique",
    "age": ["max", "min", "mean","std"],  
})
# Out:
#                   customer_id age
#                       nunique max min       mean        std
# gender
# Female                    115  79  20  49.147826  16.646607
# Male                      143  80  20  51.230769  18.462635
# Prefer not to say         742  80  20  49.725437  17.644283

# %% [markdown]
# <small>Berdasarakan keluaran diatas, kita bisa melihat bahwa data pelanggan yang kita miliki di dominasi oleh jenis kelamin Prefer not to say dan kisaran umur  antara 20 sampai 80 tahun

# %%
# Persebaran jumlah customer berdasarkan kota 
customer_df.groupby(by="city").customer_id.nunique().sort_values(ascending=False)
# Out:
# city
# East Aidan       3
# East Sophia      3
# New Ava          3
# West Jackfort    2
# Corkeryshire     2
#                 ..
# Jordanside       1
# Josephland       1
# Josephmouth      1
# Justinport       1
# Zacville         1
# Name: customer_id, Length: 961, dtype: int64

# %%
# Persebaran jumlah customer berdasarkan negara
customer_df.groupby(by="state").customer_id.nunique().sort_values(ascending=False)
# Out:
# state
# South Australia                 139
# Queensland                      134
# New South Wales                 132
# Northern Territory              125
# Western Australia               124
# Australian Capital Territory    121
# Victoria                        121
# Tasmania                        104
# Name: customer_id, dtype: int64

# %% [markdown]
# <small>Berdasarkan hasil di atas, dapat kita lihat  bahwa persebaran customer cukup merata pada setiap kota dan negara bagian. Customer paling banyak berada di kota East Aidan, East Sophia, dan New Ava dengan jumlah masing-masing tiga

# %% [markdown]
# <h3>2. Eksplorasi Data orders_df

# %% [markdown]
# <small>Kita tambahkan satu kolom lagi untuk data orders_df untuk memuat waktu pengiriman, dimana ini adalah selisih antar ***delivery_date*** dan ***order_date*** serta menyimpannya sebagai ***delivery_time***

# %%
delivery_time = orders_df["delivery_date"] - orders_df["order_date"]
delivery_time = delivery_time.apply(lambda x: x.total_seconds())
orders_df["delivery_time"] = round(delivery_time/86400)

orders_df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date  delivery_time
# 0         1           64    30811 2021-08-30    2021-09-24           25.0
# 1         2          473    50490 2021-02-03    2021-02-13           10.0
# 2         3          774    46763 2021-10-08    2021-11-03           26.0
# 3         4          433    39782 2021-05-06    2021-05-19           13.0
# 4         5          441    14719 2021-03-23    2021-03-24            1.0

# %%
orders_df.describe(include="all")
# Out:
#           order_id  customer_id       payment                  order_date  \
# count  1000.000000  1000.000000   1000.000000                        1000
# mean    500.500000   506.640000  33972.936000  2021-05-27 18:38:52.800000
# min       1.000000     1.000000  10043.000000         2021-01-01 00:00:00
# 25%     250.750000   275.250000  21329.250000         2021-03-13 18:00:00
# 50%     500.500000   515.000000  33697.500000         2021-05-27 12:00:00
# 75%     750.250000   737.250000  46249.000000         2021-08-12 06:00:00
# max    1000.000000  1000.000000  59910.000000         2021-10-24 00:00:00
# std     288.819436   277.115502  14451.609047                         NaN
#
#              delivery_date  delivery_time
# count                 1000    1000.000000
# mean   2021-06-10 20:31:12      14.078000
# min    2021-01-03 00:00:00       1.000000
# 25%    2021-03-28 00:00:00       8.000000
# 50%    2021-06-11 12:00:00      14.000000
# 75%    2021-08-24 06:00:00      21.000000
# ...

# %% [markdown]
# <small>Berdasarkan hasil diatas, rata-rata waktu pengiriman sebesar 14 hari dengan nilai maksimum sebesar 27 hari dan nilai minimum sebesar 1 hari.

# %% [markdown]
# <h3>3. Eksplorasi Data orders_df dan customers_df

# %% [markdown]
# <small> Dalam data orders_df, kita dapat mengidentifikasi pelanggan yang belum pernah order dengan menambahkan kolom "status" pada data customers_df. Pelanggan yang pernah order akan memiliki nilai "Active", sementara yang belum akan memiliki nilai "Non Active". Berikut adalah kode untuk tugas tersebut.

# %%
customer_id_in_orders_df =  orders_df.customer_id.tolist()
customer_df["status"] = customer_df["customer_id"].apply(lambda x: "Active" if x in customer_id_in_orders_df else "Non Active")
customer_df.sample(5)
# Out:
#      customer_id customer_name             gender  age  \
# 750          748     fulan 748             Female   77
# 874          870     fulan 870  Prefer not to say   49
# 59            60      fulan 60  Prefer not to say   20
# 395          395     fulan 395  Prefer not to say   70
# 12            13      fulan 13               Male   42
#
#                     home_address  zip_code              city  \
# 750   4884 Piper StreetSuite 926      5104       South James
# 874     81 Heidi MeadowSuite 615       201  Lake Ashleyhaven
# 59   8095 Kuhlman StreetApt. 657      4907        New Callum
# 395    8469 Tahlia PassSuite 409      3499        Lake Oscar
# 12         16 Kuhn LoopSuite 442      6170     Maddisonmouth
#
#                   state    country      status
# 750          Queensland  Australia  Non Active
# 874          Queensland  Australia      Active
# 59             Tasmania  Australia      Active
# 395  Northern Territory  Australia  Non Active
# ...

# %%
customer_df.groupby(by="status").customer_id.count()
# Out:
# status
# Active        617
# Non Active    384
# Name: customer_id, dtype: int64

# %% [markdown]
# <small>Dari hasil diatas, kita bisa lihat bahwa ada sekitar 384 pelanggan yang belum pernah melakukan transaksi dan ada 617 yang sudah pernah melakukan transaksi.
# Untuk memperoleh lebih banyak informasi terkait kedua data tersebut, kita perlu menggabungkan keduanya melalui proses join atau merge

# %%
orders_customer_df = pd.merge(
    left=orders_df,
    right=customer_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
orders_customer_df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date  delivery_time  \
# 0         1           64    30811 2021-08-30    2021-09-24           25.0
# 1         2          473    50490 2021-02-03    2021-02-13           10.0
# 2         3          774    46763 2021-10-08    2021-11-03           26.0
# 3         4          433    39782 2021-05-06    2021-05-19           13.0
# 4         5          441    14719 2021-03-23    2021-03-24            1.0
#
#   customer_name             gender  age                   home_address  \
# 0      fulan 64  Prefer not to say   75      4927 Alice MeadowApt. 960
# 1     fulan 473               Male   61  531 Schmitt BoulevardApt. 010
# 2     fulan 774  Prefer not to say   34       2096 Wilson MewsApt. 714
# 3     fulan 433  Prefer not to say   46        5777 Mayer PassApt. 881
# 4     fulan 441  Prefer not to say   53   33 Richards JunctionApt. 478
#
#    zip_code                city              state    country  status
# ...

# %%
# Jumlah order berdasarkan kota
orders_customer_df.groupby(by="city").order_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#                city  order_id
# 0        Jordanside         6
# 1           New Ava         6
# 2         Lake Rose         5
# 3        O'keefeton         5
# 4          East Max         5
# 5  Port Hannahburgh         5
# 6          Rubyfort         5
# 7          West Kai         5
# 8     Andrewborough         4
# 9     Port Aaronton         4

# %%
# Jumlah order berdasarkan state
orders_customer_df.groupby(by="state").order_id.nunique().sort_values(ascending=False)
# Out:
# state
# South Australia                 148
# Queensland                      139
# Western Australia               130
# New South Wales                 129
# Australian Capital Territory    118
# Victoria                        118
# Tasmania                        112
# Northern Territory              106
# Name: order_id, dtype: int64

# %%
# Jumlah order berdasarkan gender
orders_customer_df.groupby(by="gender").order_id.nunique().sort_values(ascending=False)
# Out:
# gender
# Prefer not to say    725
# Female               139
# Male                 136
# Name: order_id, dtype: int64

# %%
# Jumlah order berdasarkan usia
orders_customer_df.groupby(by="age").order_id.nunique().sort_values(ascending=False)
# Out:
# age
# 57    34
# 75    27
# 32    27
# 38    26
# 63    26
#       ..
# 72     8
# 29     8
# 77     8
# 33     7
# 65     7
# Name: order_id, Length: 61, dtype: int64

# %% [markdown]
# <small>Kita dapat mengeksplor jumlah order berdasarkan kelompok usia dengan membuat kolom baru "age_group", yang akan mengelompokkan pelanggan ke dalam tiga kategori: youth, adults, dan seniors.

# %%
orders_customer_df["age_group"] = orders_customer_df.age.apply(lambda x: "Youth" if x <= 24 else ("Seniors" if x > 64 else "Adults"))
orders_customer_df.groupby(by="age_group").order_id.nunique().sort_values(ascending=False)
# Out:
# age_group
# Adults     681
# Seniors    226
# Youth       93
# Name: order_id, dtype: int64

# %% [markdown]
# <small>Pelanggan yang paling banyak melakukan order berasal dari kelompok usia Adults.

# %% [markdown]
# <h3>4. Eksplorasi Data product_df dan sales_df

# %%
products_df.describe(include="all")
# Out:
#          product_id product_type product_name  size colour        price  \
# count   1260.000000         1260         1260  1260   1260  1260.000000
# unique          NaN            3           35     8      7          NaN
# top             NaN        Shirt        Denim    XS    red          NaN
# freq            NaN          420           70   252    180          NaN
# mean     629.500000          NaN          NaN   NaN    NaN   105.805556
# std      363.874979          NaN          NaN   NaN    NaN     9.704423
# min        0.000000          NaN          NaN   NaN    NaN    90.000000
# 25%      314.750000          NaN          NaN   NaN    NaN    95.750000
# 50%      629.500000          NaN          NaN   NaN    NaN   108.500000
# 75%      944.250000          NaN          NaN   NaN    NaN   114.000000
# max     1259.000000          NaN          NaN   NaN    NaN   119.000000
#
#            quantity                                   description
# ...

# %%
sales_df.describe(include="all")
# Out:
#           sales_id     order_id   product_id  price_per_unit    quantity  \
# count  5000.000000  5000.000000  5000.000000     5000.000000  5000.00000
# mean   2499.500000   503.038200   634.053200      103.501600     1.99240
# std    1443.520003   285.964418   363.255794        9.195004     0.80751
# min       0.000000     1.000000     1.000000       90.000000     1.00000
# 25%    1249.750000   258.000000   323.000000       95.000000     1.00000
# 50%    2499.500000   504.500000   635.000000      102.000000     2.00000
# 75%    3749.250000   749.000000   951.000000      112.000000     3.00000
# max    4999.000000   999.000000  1259.000000      119.000000     3.00000
#
#        total_price
# count  5000.000000
# mean    206.360000
# std      86.357457
# min      90.000000
# 25%     112.000000
# 50%     204.000000
# 75%     285.000000
# max     357.000000

# %% [markdown]
# <small>Berdasarkan hasil diatas,harga barang yang dijual berkisar antara 90 hingga 119 dolar.Kemudian pada setiap transaksi,  pelanggan paling banyak membeli 3 buah item dalam satu jenis produk dengan total harga sebesar 357 dolar.

# %%
# Produk yang memiliki harga terendah dan termahal
products_df.sort_values(by="price", ascending=False).reset_index(drop=True).loc[[0, len(products_df)-1]]
# Out:
#       product_id product_type product_name size  colour  price  quantity  \
# 0            698       Jacket        Parka    L  violet    119        53
# 1259         593       Jacket       Bomber    L  violet     90        68
#
#                                     description
# 0      A violet coloured, L sized, Parka Jacket
# 1259  A violet coloured, L sized, Bomber Jacket

# %%
products_df.groupby(by="product_type").agg({
    "product_id": "nunique",
    "quantity": "sum",
    "price":  ["min", "max"]
})
# Out:
#              product_id quantity price
#                 nunique      sum   min  max
# product_type
# Jacket              420    25387    90  119
# Shirt               420    25263    92  119
# Trousers            420    25139    90  119

# %%
products_df.groupby(by="product_name").agg({
    "product_id": "nunique",
    "quantity": "sum",
    "price": ["min", "max"]
})
# Out:
#                   product_id quantity price
#                      nunique      sum   min  max
# product_name
# Bomber                    35     2083    90   90
# Camp Collared             35     2071   112  112
# Cardigan                  35     2032   118  118
# Cargo Pants               35     2146   106  106
# Casual Slim Fit           35     2086   113  113
# Chambray                  35     2020   105  105
# Chinos                    35     2101   100  100
# Coach                     35     2158   115  115
# Cords                     35     2260   113  113
# Cropped                   35     2085    99   99
# Cuban Collar              35     2017    93   93
# Denim                     70     4204    92  115
# Drawstring                35     2042   104  104
# Dress                     35     2125   119  119
# Flannel                   35     2135    96   96
# Henley                    35     2051    92   92
# High-Waisted              35     2198    98   98
# ...

# %%
products_df.groupby(by="product_name").agg({
    "product_type": "first",
    "quantity": "sum",
    "price": ["min", "max"]
})
# Out:
#                   product_type quantity price
#                          first      sum   min  max
# product_name
# Bomber                  Jacket     2083    90   90
# Camp Collared            Shirt     2071   112  112
# Cardigan                Jacket     2032   118  118
# Cargo Pants           Trousers     2146   106  106
# Casual Slim Fit          Shirt     2086   113  113
# Chambray                 Shirt     2020   105  105
# Chinos                Trousers     2101   100  100
# Coach                   Jacket     2158   115  115
# Cords                 Trousers     2260   113  113
# Cropped               Trousers     2085    99   99
# Cuban Collar             Shirt     2017    93   93
# Denim                    Shirt     4204    92  115
# Drawstring            Trousers     2042   104  104
# Dress                    Shirt     2125   119  119
# Flannel                  Shirt     2135    96   96
# Henley                   Shirt     2051    92   92
# ...

# %%
##Produk paling laris
sales_product_df = pd.merge(
    left=sales_df,
    right=products_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
sales_product_df.head()
# Out:
#    sales_id  order_id  product_id  price_per_unit  quantity_x  total_price  \
# 0         0         1         218             106           2          212
# 1         1         1         481             118           1          118
# 2         2         1           2              96           3          288
# 3         3         1        1002             106           2          212
# 4         4         1         691             113           3          339
#
#   product_type  product_name size  colour  price  quantity_y  \
# 0        Shirt      Chambray    L  orange    105          44
# 1       Jacket        Puffer    S  indigo    110          62
# 2        Shirt  Oxford Cloth    M     red    114          54
# 3     Trousers          Wool    M    blue    111          52
# 4       Jacket         Parka    S  indigo    119          53
#
#                                    description
# 0   A orange coloured, L sized, Chambray Shirt
# 1    A indigo coloured, S sized, Puffer Jacket
# ...

# %%
sales_product_df.groupby(by="product_type").agg({
    "sales_id": "nunique",
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#               sales_id  quantity_x  total_price
# product_type
# Jacket            1676        3343       357026
# Shirt             1641        3259       333600
# Trousers          1683        3360       341174

# %% [markdown]
# <small>Jika kita perhatikan pivot table di atas, Trousers merupakan tipe produk yang paling laris. Akan tetapi, jika dilihat lagi berdasarkan revenue yang diterima, Jacket merupakan tipe produk yang paling banyak menyumbang revenue perusahaan.

# %%
sales_product_df.groupby(by="product_name").agg({
    "sales_id": "nunique",
    "quantity_x": "sum",
    "total_price": "sum"
}).sort_values(by="total_price", ascending=False)
# Out:
#                    sales_id  quantity_x  total_price
# product_name
# Denim                   273         527        52399
# Casual Slim Fit         154         306        36414
# Trench Coat             146         299        35581
# Shearling               150         302        35334
# Puffer                  140         298        35164
# Flannel                 141         281        33158
# Cropped                 135         284        32660
# Pleated                 147         308        32340
# Joggers                 164         334        31062
# Chambray                141         290        30740
# Parka                   134         269        30397
# Bomber                  150         297        29700
# Chinos                  135         260        29380
# Windbreaker             143         287        29274
# Cardigan                134         260        29120
# Peacoat                 132         266        28994
# ...

# %% [markdown]
# <small>Berdasarkan pivot table tersebut, produk Denim adalah  produk yang paling laris dan juga paling banyak menyumbang revenue terhadap perusahaan.

# %% [markdown]
# <h3>5. Eksplorasi Data all_df

# %% [markdown]
# <small>Kita perlu membuat sebuah DataFrame baru bernama all_df untuk menampung semua informasi dari keempat tabel di atas

# %%
all_df = pd.merge(
    left=sales_product_df,
    right=orders_customer_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
all_df.head()
# Out:
#    sales_id  order_id  product_id  price_per_unit  quantity_x  total_price  \
# 0         0         1         218             106           2          212
# 1         1         1         481             118           1          118
# 2         2         1           2              96           3          288
# 3         3         1        1002             106           2          212
# 4         4         1         691             113           3          339
#
#   product_type  product_name size  colour  ...  customer_name  \
# 0        Shirt      Chambray    L  orange  ...       fulan 64
# 1       Jacket        Puffer    S  indigo  ...       fulan 64
# 2        Shirt  Oxford Cloth    M     red  ...       fulan 64
# 3     Trousers          Wool    M    blue  ...       fulan 64
# 4       Jacket         Parka    S  indigo  ...       fulan 64
#
#               gender age               home_address  zip_code            city  \
# ...

# %%
# preferensi pembelian berdasarkan state pelanggan dan tipe produk 
all_df.groupby(by=["state", "product_type"]).agg({
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#                                            quantity_x  total_price
# state                        product_type
# Australian Capital Territory Jacket               406        43204
#                              Shirt                396        40448
#                              Trousers             454        46790
# New South Wales              Jacket               451        47998
#                              Shirt                431        43980
#                              Trousers             392        39766
# Northern Territory           Jacket               365        38991
#                              Shirt                336        33865
#                              Trousers             384        38998
# Queensland                   Jacket               499        53511
#                              Shirt                417        42506
#                              Trousers             453        46045
# ...

# %%
# negara bagian yuang paling banyak membeli Shirt
all_df[all_df["product_type"]=="Shirt"].groupby(by="state").agg({
    "quantity_x": "sum",
    "total_price": "sum"
}).sort_values(by="quantity_x", ascending=False)
# Out:
#                               quantity_x  total_price
# state
# South Australia                      509        52685
# New South Wales                      431        43980
# Queensland                           417        42506
# Australian Capital Territory         396        40448
# Western Australia                    393        40242
# Victoria                             390        40206
# Tasmania                             387        39668
# Northern Territory                   336        33865

# %% [markdown]
# <small>Berdasarkan hasil diatas, tipe produk Shirt paling banyak terjual pada negara bagian South Australia, New South Wales dan Qessnsland

# %%
# Negara bagian yang paling banyak membeli Jacket
all_df[all_df["product_type"]=="Jacket"].groupby(by="state").agg({
    "quantity_x": "sum",
    "total_price": "sum"
}).sort_values(by="quantity_x", ascending=False)
# Out:
#                               quantity_x  total_price
# state
# Queensland                           499        53511
# South Australia                      461        49090
# New South Wales                      451        47998
# Tasmania                             412        44370
# Australian Capital Territory         406        43204
# Western Australia                    390        41659
# Northern Territory                   365        38991
# Victoria                             359        38203

# %% [markdown]
# <small>Berdasarkan hasil diatas, tipe produk Jacket paling banyak terjual pada negara bagian Queensland, South Australia, dan New South Wales

# %%
# Negara bagian yang paling banyak membeli Trousers
all_df[all_df["product_type"]=="Trousers"].groupby(by="state").agg({
    "quantity_x": "sum",
    "total_price": "sum"
}).sort_values(by="quantity_x", ascending=False)
# Out:
#                               quantity_x  total_price
# state
# South Australia                      455        46041
# Australian Capital Territory         454        46790
# Queensland                           453        46045
# Western Australia                    429        43529
# Victoria                             414        41948
# New South Wales                      392        39766
# Northern Territory                   384        38998
# Tasmania                             379        38057

# %% [markdown]
# <small>Berdasarkan hasil diatas, tipe produk Trouses paling banyak terjual pada negara bagian South Australia, Australian Capital Territory,  danQueensland

# %%
# tipe produk pelanggan berdasarkan gender
all_df.groupby(by=["gender", "product_type"]).agg({
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#                                 quantity_x  total_price
# gender            product_type
# Female            Jacket               481        50963
#                   Shirt                445        45146
#                   Trousers             481        49295
# Male              Jacket               480        50978
#                   Shirt                410        41939
#                   Trousers             453        46071
# Prefer not to say Jacket              2382       255085
#                   Shirt               2404       246515
#                   Trousers            2426       245808

# %% [markdown]
# <small>Berdasarkan hasil diatas, gender  female membeli Jacket dan Trousers, gender  male  lebih banyak membeli Jacket dan gender Prefer not to say  lebih banyak membeli Trousers

# %%
# tipe produk pelanggan berdasarkan kelompok usia.
all_df.groupby(by=["age_group", "product_type"]).agg({
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#                         quantity_x  total_price
# age_group product_type
# Adults    Jacket              2292       245055
#           Shirt               2225       227781
#           Trousers            2272       231271
# Seniors   Jacket               777        82959
#           Shirt                733        74977
#           Trousers             766        77471
# Youth     Jacket               274        29012
#           Shirt                301        30842
#           Trousers             322        32432

# %% [markdown]
# <small>Berdasarkan hasil diatas, kelompok usia Adults lebih banyak membeli Jacket, kelompok usia seniors lebih banyak membeli Jacket dan Kelompok usia Youth lebih banyak membeli Trousers
